# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n=10000
a=0
b=1
data = np.random.uniform (a,b,n)

# %%
data
# Out:
# array([0.05028476, 0.10519362, 0.51141881, ..., 0.79198565, 0.24844745,
#        0.95865871])

# %%
type (data)
# Out:
# numpy.ndarray

# %%
len(data)
# Out:
# 100

# %%
t=range(len(data))

# %%
t
# Out:
# range(0, 10)

# %%
len(t)
# Out:
# 100

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([1034.,  931.,  945., 1011.,  976., 1026., 1083., 1044.,  984.,
#          966.]),
#  array([4.04297975e-05, 1.00023799e-01, 2.00007167e-01, 2.99990536e-01,
#         3.99973905e-01, 4.99957274e-01, 5.99940642e-01, 6.99924011e-01,
#         7.99907380e-01, 8.99890749e-01, 9.99874117e-01]),
#  <a list of 10 Patch objects>)

# %%
data= np.random.randn(n)
x=range(1,n+1)

# %%
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([  15.,   97.,  486., 1383., 2585., 2807., 1772.,  694.,  136.,
#           25.]),
#  array([-3.72813906, -3.00332619, -2.27851332, -1.55370045, -0.82888758,
#         -0.10407471,  0.62073817,  1.34555104,  2.07036391,  2.79517678,
#          3.51998965]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
errores=np.random.randn(n)

# %%
sigma=5

# %%
errores *=sigma

# %%
plt.hist(errores)
# Out:
# (array([  20.,  175.,  792., 2120., 2963., 2481., 1148.,  263.,   35.,
#            3.]), array([-18.19376016, -14.27071498, -10.3476698 ,  -6.42462462,
#          -2.50157944,   1.42146574,   5.34451091,   9.26755609,
#          13.19060127,  17.11364645,  21.03669163]), <a list of 10 Patch objects>)

# %%
np.var(errores)
# Out:
# 24.962801414259395

# %%
x = range(0,n)

# %%
a=0
b=1

# %%
len(x)
# Out:
# 10000

# %%
len(errores)
# Out:
# 10000

# %%
y=a+b*

# %%
#importar datos
url_datos="http://winterolympicsmedals.com/medals.csv"

# %%
models_data=pd.read_csv(url_datos)

# %%
models_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold
